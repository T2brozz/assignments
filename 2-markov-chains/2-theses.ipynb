# %% [markdown]
# # Assignment 2: Theses

# %% [markdown]
# ---
#
# ## Task 2) Theses Inspiration
#
# Imagine you'd have to write another thesis, and you just can't find a good topic to work on.
# Well, n-grams to the rescue!
# Download the `theses.txt` data set from the `Supplemental Materials` in the `Files` section of our Microsoft Teams group.
# This dataset consists of approx. 1,000 theses topics chosen by students in the past.
#
# In this assignment, you will be sampling from n-grams to generate new potential thesis topics.
# Pay extra attention to preprocessing: How would you handle hyphenated words and acronyms/abbreviations?
#
# *In this Jupyter Notebook, we will provide the steps to solve this task and give hints via functions & comments. However, code modifications (e.g., function naming, arguments) and implementation of additional helper functions & classes are allowed. The code aims to help you get started.*
#
# ---

# %%
import nltk
import pandas as pd
import regex as re
import sklearn as sk

# %% [markdown]
# ### Prepare the Data
#
# 1.1 Spend some time on pre-processing. How would you handle hyphenated words and abbreviations/acronyms?

# %%
def load_theses_titles(filepath):
    """Loads all theses titles and returns them as a list."""
    ### YOUR CODE HERE
    
  
    
    data= pd.read_csv(filepath, sep='\t', encoding='utf-8', header=None)
    data = data[3].to_list()
    return data
    ### END YOUR CODE

# %%
load_theses_titles("./data/theses.tsv")
# Out:
# ['EMail am Beispiel SMTP im Internet',
#  'Einführung des Configuration Management-Systems PCMS zur strukturierten Versions-Release- und Änderungskontrolle in Projekten der Abteilung Information-Systems der Firma Motorola',
#  'Analyse und Leistungsvergleich von zwei Echtzeitsystemen für eingebettete Anwendungen',
#  'Erfassung und automatische Zuordnung von Auftragsdaten für ein Dienstleistungsunternehmen mit Hilfe von Standardsoftware - Konzeption und Realisierung',
#  'Organisationskonzept zur Administration von Lehrgangsrechnern für eine DV-Fortbildungsinstitution',
#  'Monte Carlo-Simulation für ein gekoppeltes Round-Robin-System',
#  'Untersuchung der elektrischen Eigenschaften von Supraleitern mit Hilfe eines Gas-Kryosystems',
#  'Prioritätsfreies Scheduling in verteilten Echtzeit-Systemen unter Berücksichtigung von Zeit- und Betriebsmittelanforderungen',
#  'Implementierung eines Testüberdeckungsgrad-Analysators für RAS',
#  'Eine objektorientierte Fuzzy-Entwicklungsumgebung - Entwurf und Implementierung des Kerns',
#  'Eine objektorientierte Fuzzy-Entwicklungsumgebung - Entwurf und Implementierung der Bedienoberfläche',
#  'Strukturierung und Dokumentenmanagement von Gebrauchsanweisungen auf der Basis von SGML',
#  'Untersuchung von 4 Netzwerksystemen im Hinblick auf ihre Einsatzmöglichkeiten insbesondere im Weitverkehrsnetz einer EDV-Dienstleistungsfirma',
#  'Erstellung eines Konzeptes zur Umstellung eines bestehenden Netzwerkmanagementsystems von CMIP/CMOL auf SNMP',
#  'Migration der Bearbeitung des Schriftverkehrs der Kreissparkasse Nürnberg von einem großrechnerorientierten System auf eine Client-Server-Architektur (Arbeitstitel)',
#  'Lösung von Zuordnungsproblemen unter Berücksichtigung verschiedenartiger Randbedingungen beim Verkabeln einer Vermittlungsanlage',
#  'Konzeption und Realisierung eines multimedialen Sammlerkataloges am Beispiel "altes Spielzeug"',
#  'Analyse und Konzeption der zukünftigen Informatikunterstützung für ein Ing.-Büro',
#  'Konzeption eines Netzwerkmanagementsystems für eine heterogene Netzwerkumgebung',
#  'Aufbau, Inbetriebnahme und Optimierung eines hoch repetierlichen Ho: YAG-Laser für med. Anwendung',
#  'Untersuchung verschiedener Lernverfahren für Neuro-Fuzzy-Systeme',
#  'Untersuchung der Echtzeit-Eignung eines Betriebssystems am Beispiel von Varianten des UNIX-Kerns',
#  'Schnelle Berechnung von Ray-Tracing-Animationen durch Voxelisierung des Szenenraums',
#  'Computergestützte und kundenorientierte Erfassung und Verarbeitung von Gesteinsprobensiebwerten zur Bestimmung eines optimalen Mischungsverhältnisses',
#  'Rechnergestützte Einzelworterkennung. Ein Vergleich von Methoden zur Analyse und Klassifikation',
#  'Komprimierung, Übertragung, Auswertung und Aufbereitung von Meßdaten aus einer Solaranlage',
#  'Redesign und aTRACktive-Datenbank und Portierung des Auswertungssystems auf einem PC',
#  'Computergestützte Wertstoffsammlung',
#  'Entwurf und Implementierung einer offenen Schnittstelle zum Repository eines CASE-Tools mittels der Standard-Skript-Sprache TCL',
#  'Einführung der digitalen Dokumentenannahme und -verarbeitung in einem Kleinbetrieb der Druckindustrie',
#  'Portierung der hardwarenahen Komponenten des Echtzeitbetriebssystems EUROS auf die Alpha-Architektur',
#  'Erstellung eines aktiven Kommunikationsmoduls mit "Gateway"-Eigenschaften im Prozeßleitbereich unter OSF/1',
#  'Auswahl und Implementierung von Kommunikationswerkzeugen zum Datenaustausch zwischen Windows- und UNIX-Systemen. Einsatz der Werkzeuge im Rahmen eines BDE-Systems',
#  'Sinnentstellung bei der Übersetzung englischsprachiger Fachbücher ins deutsche und deren Ursachen. Eine linguistische Untersuchung für Informatiker "Übergehen Sie die Elementfunktion um die Ikone ..."',
#  'Entwicklung eines plattformunabhängigen 3964R-Treibers für Windows-NT',
#  'RSA-Schlüsselgenerierung im Siemens Chipkartenprozessor SLE 44 C 200',
#  'Konzeption und Erstellung einer Klassenbibliothek für Benutzeroberflächen in der Automatisierungstechnik',
#  'Parallelverarbeitung im Workstation-Verbund. Implementierung ausgewählter Beispielanwendungen mit Hilfe geeigneter Werkzeuge',
#  'Konzeption und Modellierung eines Unternehmens-Führungs-Systems (UFS) für ein Dienstleistungsunternehmen und Realisierung der Teilkomponenten Mitarbeiter- und Projektverwaltung',
#  'Telearbeit in einem Industriebetrieb der Elektrobranche - Einsatzmöglichkeiten, technische, organisatorische und rechtliche Rahmenbedingungen',
#  'Notfallkonzept zur Steigerung der Verfügbarkeit einer bestehenden IT/DV-Infrastruktur innerhalb der SAG, basierend auf Compaq-HW mit MS-NTAS Betriebssystem',
#  'Erstellung und Einführung eines grafisch-interaktiven Systems zur Unterstützung von Administration und Controlling der Unterschriftenregelung',
#  'Analyse, Design und Implementierung des Bereichs Ausschreibung eines AVA-Programms mit objektorientierten Methoden',
#  'Erstellung eines Bibliothekskonzeptes zur Verwaltung versionierter, über OLE-Technik verbundener Objekte. Realisierung der Basisfunktionalität des Konzeptes basierend auf OLE 2',
#  'Einsatzmöglichkeit von kooperativen Systemen am Beispiel eines Unternehmens im Maschinenbau',
#  'Arbeitstitel: Darstellung der Information neuronaler Netze in chemischen Anwendungen',
#  'Kern eines Simulationswerkzeuges für AWL-Programmstrukturen und Tasks nach SPS-Norm IEC 1131',
#  'Umsetzung eines Logistik Controlling Verfahrens von einer lokalen PC-Version auf eine Client Server Umgebung unter SAP R/3',
#  'Überarbeitung des Einkaufscontrollings und DV-technische Realisierung mittels SAP R/3 bei einem Konzernunternehmen',
#  'Zielvereinbarungen und Prozeßkenngrößen. Eine Maßnahme zur Einführung von Total Quality Management',
#  'Konzeption und Realisierung einer Netzterminierung als Bestandteil des graphischen Leitstandes SIFLEX',
#  'Ablösung des DESTI UNIX-Verfahrens durch eine Client-Server Applikation',
#  'Adaptive Parametrierung einer Image-Hardwarepipeline',
#  'Konzept für das Management von Online-Diensten im Internet',
#  'Konzeption und Realisierung einer Datenbankanwendung für die Kundenbetreuung am Beispiel der Firma S.E.P.P.',
#  'Einrichtung einer Datenbasis für die Hardware-Dokumentation des Netzwerks einer Großfirmenniederlassung',
#  'Neuorientierung des Management-Accounting in einer Bank',
#  'Entwurf und Teilimplementierung von Backup- und Restore-Verfahren für eine Festplatte auf DRAM-Basis',
#  'Analyse, Design und Implementierung der Bereiche Vergabe und Kostenkontrolle eines AVA-Programmes mit objektorientierten Methoden',
#  'Datenbanken in parallelen Rechnerarchitekturen',
#  'Die Bedienoberfläche für ein System von Kfz-Testgeräten - Simulation und Entwicklung eines objektorientierten Modells',
#  'Konzeption und Realisierung einer computerunterstützten Unterrichtseinheit für HTML auf der Basis von Asymetri Todbock',
#  'Datenintegration in der Dermatologischen Universitätsklinik Erlangen: Migration von Insellösungen zu einer integrierten Datenbank-Anwendung (Arbeitstitel).',
#  'Einführung eines kundenorientierten Qualitätsmanagements in Verkauf und Service einer Unternehmung der Bürotechnik-Branche',
#  'Fraktale Bildkompression. Entwurf, Realisierung und Vergleich von Methoden der Bildcodierung und Decodierung',
#  'Ein Fachkonzept zur Integration der bestehenden DV-Insellösungen für CAD und PPS der Firma Hydrometer GmbH',
#  'Algorithmen zur automatischen Regelinduktion aus Tabellenwissen',
#  'Erstellung eines Software-Assistenten zur Unterstützung bei der Projektierung von Netzwerksystemen in der Automatisierungstechnik',
#  'Entwicklung eines Werkzeugs zur Selektion von Analysedaten  - formale Datenbeschreibung, Vorübersetzung, Interpretation',
#  'Entwurf eines Entwicklungskonzeptes zur Erstellung von Client-/Server-Datenbankanwendungen mit CA OpenRoad für den Bereich Software Factory/Tool Support',
#  'Erstellen eines Outsourcing-Konzeptes und Durchführung einer Angebotsphase',
#  'Spezifikation und Teilimplementierung eines Produktionsleitstandes im Bereich Tabakvorbereitung',
#  'Erstellen eines interaktiven Telegramminterpreters zur Simulation von Telegrammen in einem bestehenden Kommunikationssystem. Erarbeiten der nötigen Funktionen, Konzepterstellung, Realisierung mit Visu',
#  'OLE als Object Request Broker, demonstriert an einem Beispiel für die Lehre',
#  'Entwicklung medizinspezifischer Standardkomponenten auf der Basis von OLE',
#  'DV-technische Unterstützung einer effektiven Werksinstandhaltung unter Einsatz von Datenbanken am Beispiel eines Werkes für medizinische Geräte',
#  'Entwurf und Implementierung einer Speicherverwaltung mit "Garbage-Collector"',
#  'Konzept über den Einsatz neuer Medien für einen regionalen Fernsehsender',
#  'Vom gesprochenen Satz zum SQL-Befehl: semantische Schlüsselwortanalyse natürlich sprachlicher Datenbankabfragen im Verbund mit einem Spracherkennungssystem',
#  'Entwicklung eines Werkzeugs zur Querübersetzung der Sprache "Strukturierter Text" in die Sprache "Anweisungsliste" für die Programmierung von SPS-Steuerungen nach IEC 1131-3 Base-Level',
#  'Analyse eines bestehenden Programmsystems hinsichtlich konzeptioneller und struktureller Optimierung',
#  'Entwurf und Implementierung eines Testdatengenerators für C++ Klassen',
#  'Zertifizierung nach DIN EN 9001. Einführung und EDV-Unterstützung in einem kunststoffverarbeitenden Betrieb',
#  'Anwendung von Methoden und Techniken des Compilerbaus auf natürlich-sprachliche Texte zur Erkennung formal definierter Textstrukturen in juristischen Texten',
#  'Authentifizierung von Internet/Intranet Anwendern - Lösungsansätze und Realisierung mittels Chipkarte unter Verwendung von "Java"',
#  'Definition und Realisierung einer generischen, objektorientierten Datenbank-Schnittstelle für ein ICE-Fahrgastinformationssystem',
#  'Organisations- und DV-Konzept für die Kundenbetreuung eines Dienstleistungsunternehmens',
#  'HTML-basiertes System zur kontrollierten Strukturierung und Workflowüberwachung technischer Dokumente',
#  'Aeronautical Information System',
#  'Entwurf und Realisierung eines Monitors und Debuggers für einen Digitalen Signalprozessor',
#  'Entwicklung einer Netzwerk-Komponente auf TCP/IP- und Ethernet-Basis für das Echtzeit-Betriebssystem EUROS',
#  'Objektorientiertes Testen von Frameworks und Komponenten',
#  'Optimierung der grundlegenden Arbeitsabläufe einer Volkshochschule mit einem EDV-System am Beispiel der VHS-Forchheim. Teilsystem 2: Teilnahme und Abrechnung',
#  'Optimieirung der grundlegenden Arbeitsabläufe einer Volkshochschule mit einem EDV-System am Beispiel der VHS-Forchheim. Teilsystem 1: Stammdatenverwaltung und Kursplanung',
#  'Entwicklung eines Streams Moduls, welches das IEC 870 - 5 - 101 Protokoll auf Verbindungsebene unter SUN Solaris 2.4 realisiert',
#  'Optimierung des Echtzeit-Verhaltens der File-Systeme im MS-DOS- und EUROS-Format für das Echtzeitbetriebssystem EUROS',
#  'Automatische Erstellung von Quellcode für grafische Benutzeroberflächen unter dem X-Window-System IMOTIF aus Resourc-Files unter MS-Windows',
#  'Transaktionsmanagement in objektorientierten Datenbank-Anwendungen am Beispiel eines AVA-Programms',
#  'Konzept für einen Informationsservice auf Intranetbasis',
#  'Konzeption und Einrichtung eines Applikationsservers für GT',
#  'Meßtechnische und rechnerische Bestimmung schalltechnischer Kennwerte in der Bauakustik',
#  'Portierung der hardwarenahen Komponenten des Echtzeitbetriebssystems EUROS auf die DEC-Alpha-Mikroprozessor-Architektur',
#  'Portierung der hardwarenahen Komponenten des Echtzeitbetriebssystems EUROS auf die Mikrokontroller-Familie C 166 für eingebettete Systeme',
#  'Wavelet Bildkompression - Entwurf, Realisierung und Vergleich von Methoden der Bildcodierung und -decodierung',
#  'Entwurf und Implementierung eines "OLE for Process Control" (OPC) Server',
#  'Verbesserung der unternehmensinternen Informationsversorgung durch EDV-gestütztes Dokumentenmanagement mit Langzeitarchivierung',
#  'Entwicklung eines Pentium TM- und MMX TM - optimierten ActiveMovieTM Software Filters für die Echtzeitkomprimierung und Dekomprimierung von Video-Datenströmen',
#  'Ein Informationssystem für ein Sprachlabor',
#  'Konzept für die Geschäftsprozeßoptimierung der Provisionsbearbeitung bei einem Versicherungskonzern',
#  'Reengeneering eines QS-Werkzeuges für eine grafische Benutzeroberfläche',
#  'Erstellung eines Konzepts zur Stammdatenhaltung konfigurierbarer Erzeugnisse in SAP R/3',
#  'Patientenregistrierung in einem medizinischen SW-System:  Realisierung der Anwendungslogik als DCOM-Komponente',
#  'Arrival Manager-Anwendung des objektorientierten Ansatzes beim Requirements-Engineering verbunden mit einer Methodendiskussion',
#  'Objektorientierte Modellierung von Softwarearchitekturen. Konzepte für die inhaltliche Ausgestaltung und Formen der Beschreibungen',
#  'Konzeption (und Realisierung) eines Verkaufsterminals für Kino-Eintrittskarten mit Platzreservierung unter Verwendung von Chipkarten für die Bezahlung (elektronische Geldbörse)',
#  'Erarbeitung eines Konzeptes zur Abrechnung des Lizenzentgeltes für Verpackungen innerhalb der Standardsoftware R/3 von SAP',
#  'Der Weg zum Niedrigenergiehaus - Entwicklung von Varianten',
#  'Messung passiver solarer Energiegewinne',
#  'Konzeption und Umsetzung eines Werkzeugs zur Anonymisierung von Datenbank-Inhalten mit dem Ziel der Erzeugung von Testdaten',
#  'Konzeption und Realisierung eines Programms zur Sicherung der Aufwärtskompatibilität eines Projektierungssystems',
#  'Entwicklung eines Protokollanalysators für das mobile Datenträgersystem MOBY-L',
#  'Untersuchung und Bewertung von SAP Business Workflow, einem Zusatztool des SAP R/3-Systems',
#  'Moderne Methoden des Requirements Engineering - Die Vorgehensweise BRE9000',
#  'Implementierung eines Datentransfers mittels TCP/IP unter einem Multitasking-Kernel für ein Kassenterminal',
#  'Multidimensionale Optimierung mit Hilfe Genetischer Algorithmen und Evolutionssstrategien am Beispiel der Stundenplanerstellung für Schulen',
#  'Untersuchung der Wärmeabgabe von Rohrleitungsarmaturen der Heiz- und Warmwasseranlagen bis DN 32',
#  'Entwurf und Entwicklung eines Frühwarnsystems zur systematischen Überwachung von frei konfigurierbaren EDV-Systemen und automatischen Beseitigung von Störungen',
#  'Optimierung eines Fuzzy-Reglers durch ein neuronales Netz am Beispiel eines mechanischen Stabilitätsproblems',
#  'Entwurf und Realisierung eines Suchsystems für elektronische Bauelemente mittels des EDM-Systems CADIM',
#  'Konzeption und Realisierung eines Multiprojektplanungssystems',
#  'Stärkung der Schlagkraft des Unternehmens am Absatzmarkt durch geeignete EDV-Unterstützung in Marketing und Vertrieb',
#  'Wareneingangsplanung',
#  'Entwurf und Realisierung eines Änderungsmanagement-Systems für Softwareentwicklung als Intranetanwendung',
#  'Entwurf und Realisierung eines objektorientierten Termin- und Ressourcenplanungssystems unter besonderer Berücksichtigung geeigneter Optimierungsalgorithmen',
#  'Realisierung einer wiederverwendbaren Softwarekomponente zur Visualisierung von Hierarchien mit Java Beans und ihre Verwendung in einer SGML-Datenbank',
#  'Untersuchung der Eignung eines objektorientierten Analyse-Modells bezüglich der Verifikation betrieblicher Anforderungen anhand eines Beispiels aus der Flugsicherung',
#  'Konzeption einer Benutzer- und Rechteverwaltung zur Integration von Windows NT-Workstations in eine bestehende heterogene Infrastruktur',
#  'Realisierung eines Windows 95-Treibers für den 3D-Steuergriff SpaceMaster',
#  'Entwicklung einer PC-CD-ROM-Steuerung zur Sprachaudiometrie und Feinanpassung von Hörgeräten',
#  'Entwurf und Implementierung der Datenreplikation für ein Vertriebsinformationssystem',
#  'Dynamisierung von statischen  Intranet-Seiten mit Hilfe einer Datenbank-Anwendung',
#  'Architektur eines komponentenbasierten Verschaltungseditors in der Automatisierungstechnik',
#  'Visualisierung interner Abläufe im Echtzeit-Betriebssystem EUROSplus unter MS-Windows',
#  'Konzeption und Realisierung eines Internet-Marketingsystems für den Geschäftsbereich Nutzlastentwicklung/Mikrogravitation der Daimler-Benz Aerospace AG',
#  'Konzeption und Realisierung eines Internet-Marketingsystems für den Geschäftsbereich Nutzlastentwicklung/Mikrogravitation der Daimler-Benz AG',
#  'Erstellung eines Sicherheitskonzeptes für das Projekt Internetserver ZKT (Zentrum für Kartenanwendungen Telekom)',
#  'Analyse und Grobkonzeption der Geschäftsprozesse des Customer Support eines IT Dienstleisters',
#  'Schutz sensibler Firmendaten und die Sicherstellung ihrer Übertragung im Internet',
#  'Abbildung zwischen objektorientierten Klassenmodellen und konzeptionellen Schemata relationaler Datenbanken im CASE-Werkzeug Innovator - Konzeption und Realisierung eines Werkzeugs',
#  'Konzeption eines Werkzeuges und Realisierung eines Prototypen zum automatisierten Testen von OLE-Komponenten',
#  'Entwicklung von Java-Beans zur Darstellung vorhandener Modelle des CAD-Systems I-DEAS auf Internet-Browsern mit VRML',
#  'Erstellen einer Meß- und Steuersoftware für Impedanzspektrometrie an Brennstoffzellen',
#  'Performancemessung und selektive Telegrammdarstellung auf dem PROFIBUS-DP',
#  'Entwurf und Implementierung eines OSEK-konformen Echtzeitbetriebssystems für den Mikrocontroller SAB 80C167',
#  'Verwaltung von Änderungen technischer Dokumente - Konzeption und Entwicklung eines Prototypen',
#  'Konzeption eines Data Warehouse im Bereich Marktforschung',
#  'Funktionskonzept und Datenmodell für die Jobverwaltung in einer Marketingagentur',
#  'Entwicklung von Lernsoftware zum Thema "Numerische Mathematik für Informatiker"',
#  'Objektorientierte Modellbildung in der Wirtschaftsinformatik',
#  'siehe lfd. Nr. 436',
#  'Integration und Steuerung eines Spektralphotometers zur automatischen Durchführung biochemischer Analytik',
#  'Entwickung, Realisierung und Test einer druckdichten Prozeßzelle für die Kristallisation von Zeolithen in einer neuartigen Mikrowellenheizanlage',
#  'Konzeption eines Marketinginformationssystems für ein unternehmerweites Leistungsspektrum',
#  'Konzeption und Implementation eines Funktionstabellen Editors für das ASIC Design',
#  'Entwurf und Realisierung eines Redaktionssystems für die automatisierte Erstellung von Internet-Seiten',
#  'Die notwendige Schulung des Programmieranfängers vor dem Einstieg in die Syntax einer speziellen Programmiersprache anhand ausgewählter Beispiele - Unterweisung im Umgang mit den formalen Konstrukten',
#  'Entwurf und Realisierung eines Sendungsverfolgungssystems unter besonderer Berücksichtigung offnerer Schnittstellen',
#  'Entwurf und Teilimplementierung einer datenbankbasierten Intranetlösung zur projektorientierten Zeiterfassung',
#  'Erkennung musikalischer Symbolschrift und Transformation nach MIDI',
#  'Entwicklung der Software zur Verwaltung einer Milchviehherde und der Steuerung eines Fütterungsautomaten zur Verteilung von Kraftfutter',
#  'Entwurf und Realisierung eines Entscheidungsunterstützungssystems. Teilweise Implementierung am Beispiel PC-Kauf.',
#  'Verbesserung und Optimierung vorhandener Werkzeuge zur verfahrenstechnischen Planung von Kraftanlagen',
#  'Internet fähige 3-Ebenen C/S Anwendung auf Basis des Framework FROC/S-Erarbeitung eines Konzepts und beispielhafte Implementierung',
#  'Konzept zur Nutzung von Internet-Technologien und prototypische Realisierung eines Teilaspektes dieses Konzeptes, angewendet auf SGML-Datenbestände der Abteilung Informationsdienste der Fa. DATEV e.G.',
#  'Untersuchung eines Debug-Systems für embedded Anwendungen unter Java',
#  'DV-Konzept und Softwareauswahl für ein mittelständiges Unternehmen',
#  'Vereinheitlichung der objektorientierten Modellierung UML - eine kritische Würdigung',
#  'Reengineeringkonzept f. ein derz. Dateiorient. Informationssystem f. techn. Komponenten unter Einsatz e.geeign. Datenbanksystems m. Mehrbenutzerzugriff und Schnittstelle z. Internet',
#  'Konzeption und Auswahl eines Management-Informations-Systems für ein Ingenieur-Büro',
#  'Das Konzept des Passivhauses in Theorie',
#  'Konzept für Backup und Recovery der Oracle-Datenbanken bei der Firma Bosch in Nürnberg',
#  'Informationssicherheit in lokalen und globalen Netzen als Gegenstand des strategischen Informationsmanagements',
#  'Entwurf und Implementierung von Kommunikationsstrategien mit CORBA am Beispiel einer Virtual-Reality-Anwendung',
#  'Untersuchung von Methoden zum unscharfen Zugriff auf Datenbestände',
#  'Konzeption und Realisierung einer DCOM-basierten Komponentenarchitektur für ein existierendes, mit TCP/IP-Sockets realisiertes Kommunikationssystem',
#  'Implementierung von Prioritätsschrankenalgorithmus und verwandten Synchronisationsverfahren zur Untersuchung des Echtzeit- und Laufzeitverhaltens',
#  'Konzeption eines Geschäftsprozeßmodells für einen Dienstleister im Bereich Internet, Datenbanken und innovative Technologien',
#  'Konzeption und Realisierung eines graphischen Editors für Objekte in der DCOM-basierten Laufzeitsystem Object Engine',
#  'Benutzeridentifikation anhand der Bedienmuster für standar. Texte mit Hilfe von Methoden der Neuronalen Netze',
#  'Komponentenbasierte 3-Ebenen-SW-Architekturen am Beispiel eines internetfähigen Informationssystems',
#  'Hochverfügbare Systeme im NT-Umfeld',
#  'Entwurf und Realisierung eines datenbankbasierten Systems zur strukturierten Verwaltung mehrsprachiger Textdokumente',
#  'IT -Unterstützung im Vertrieb - Budgetangebote im Anlagengeschäft',
#  'Untersuchung der Realisierung fuzzy-logischer Konzepte für das Datenbank-Retrieval',
#  'Entwurf und Implementierung eines Echtzeit-Betriebssystems-Kerns für den digitalen Signalprozessor Motorola 56 300',
#  'Konzeption eines Informationssystems für das Qualitätsmanagement im Produktdefinition- und -entwicklungsprozeß',
#  'Entwurf und Einführung eines skalierbaren Kommunikationskonzepts für den Mittelstand auf Basis von Komponenten und Funktionen',
#  'Automatische Robotoprogrammierung zum Zeichnen von 2 D-Grafiken',
#  'Design und Implementierung eines Werkzeugs zur computerunterstützten Dokumentation von Programmquellcode',
#  'Administration und Visualisierung von Dokumenten auf Basis verteilter Objekte in einer Mehrebenenarchitektur',
#  'Erstellen einer Verkehrslärmkarte für das Stadtgebiet Bamberg',
#  'Desaster Recovery von WINDOWS NT - Diskussion präventiver Strategien und deren Umsetzung',
#  'Entwicklung eines Open GL kompatiblen Treibers für den Grafikchip GLINT MX/Delta für das Betriebssystem Linux',
#  'Implementierung eines Systems zur automatischen und halbautomatischen Gewinnung von Unterschriften bei einer Direkt-Bank',
#  'Entwurf und Implementierung einer OLE DB-Schnittstelle für Typinformationen in COM-Umgebungen',
#  'Methoden des Software Reliability Engineering und deren Implementierung',
#  'Aufbau und Test eines Infrarotmikroskops',
#  'Die Berechnung der Abscheidung von Aerosolteilchen in Faserfiltermedien aufgrund von Trägheit und Gravitation (neues Zellenmodell)',
#  'Verwaltung zeitbezogener Daten: Grundlagen und deren Realisierung in SQL-92 und SQL 3',
#  'Konzeption, Design und Implementierung einer Portierung von Windows NT nach Windows CE am Beispiel eines Embeddet HMI Systems für Sinumerik 840 D',
#  'Konzeption eines vollständig benutzerzentrierten kommerziellen Internetangebotes',
#  'Entwicklung einer Anwendung zur Erstellung und Präsentation von Dokumenten auf Basis von Internettechnologie und verteilter Objekte in Java',
#  'Untersuchung der Implementierungs- und Realisierungsmöglichkeiten einer WAP-Anwendung',
#  'Mental Ray Shader zur realistischen Darstellung der Oberflächenspannung auf mit Flüssigkeit überzogenen Flächen',
#  'Konzeption und Realisierung eines Data Warehouse-Ansatzes am Beispiel des Business Information Warehouse der SAP AG',
#  'Konzeption und prototypische Umsetzung einer Schnittstelle zur verteilten Simulation dynamischer Produktprozesse auf Basis der High Livel Architecture',
#  'Integriertes Domtrollingkonzept für die interne und externe Rechnungslegung bei Energieversorgungsunternehmen als Folge der Liberalisierung der Energieversorgermärkte - Entwicklung und Implementierung',
#  'Softwareunterstützte Erzeugung von komplexen, verteilten Simulationsmodellen aus Einzelmodellen auf Basis der HLA',
#  'Entwicklung eines Vorgehensmodells für das Management von Projekten in der objektorientierten Software-Entwicklung',
#  'Entwurf und Realisierung von Komponenten für graphische Operationen in einem Plotmanagement-System',
#  'Entwurf und Realisation einer TAPI-Schnittstelle zur Steuerung einer ISDN-Telekommunikations-Anlage über Ethernet und Demonstration der Funktionsweise anhand einer CTI-Applikation unter LINUX',
#  'Analyse und Konzeption von Kommunikationsprozessen in einer Bank im Hinblick auf die Einführung eines Intranets',
#  'Auswertung von Stereobildern - Objekterkennung und Szenenvermessung',
#  'Entwicklung von Komponentensoftware mit Microsoft COM und der Active Template Library am Beispiel einer verteilten Groupware-Anwendung',
#  'Konzeption und Realisierungs internetfähiger Reservierungs-Komponenten am Beispiel eines Kinoverwaltungssystems',
#  'Entwicklung eines unternehmensspezifischen Zeiterfassungssystems unter Verwendung von Borland Delphi und Microsoft SQL Server',
#  'Einbindung des Internet in den Workflow des mehrspartigen Netzbauabwicklungsprozesses bei einem Energieversorger',
#  'Betrachtung des XML-basierten Internet-Objektprotokolls SOAP als Basis für Web-Applikationen der 3. Generation sowie Darstellung anhand eines durchgängigen Beispiels aus der Versicherungsbranche',
#  'Konzeption und Implementierung eines komponentenbasierten Robotersimulators',
#  'Optimierte Darstellung und Speicherung von Dreiecksnetzen',
#  'Konzept zur Einführung eines Dokumentenmanagementsystems für einen internen DV-Dienstleister',
#  'Design und Implementierung eines objektorientierten Kommunikations-Framework',
#  'Entwurf und Teilrealisierung eines betrieblichen Internet-Informationssystems',
#  'Konzept für ein Qualitätsinformationssystem zur Auswertung von technischen Daten mit Hilfe eines Data-Warehouse auf Basis der OLAP-Technologie',
#  'Entwicklung und Evaluierung verschiedener Middlewarekonzepte als Simulationsumgebung für GSM (Gloal System for Mobile Communication) - Sprachverarbeitung',
#  'Interaktion mit einem Internet-Agenten',
#  'Analyse der Methoden des Information Retrieval von Suchmaschinen und prototypische Implementierung geeigneter Anwendungen',
#  'Evaluierung der möglichen Integration von SAP Secure Network Communication in die Siemens TranSON Architektur',
#  'Entwurf eines Risikomanagementsystems unter besonderer Berücksichtigung der Aggregation von Risiken',
#  'Entwicklung von Algorithmen zur Erkennung von Augen in digitalen Bildern',
#  'Entwurf und Realisierung eines modularen und interaktiven Bildverarbeitungssystems',
#  'Development of a fault tolerant solution for a PC-based Programmable Logic Controller',
#  'HyTime-basiertes Link-Management in einem SGML-Content Management-System',
#  'Entwicklung einer Ausführungsumgebung von Komponenten in verteilten Systemen',
#  'Entwurf und Entwicklung einer XML-basierten Beschreibungssprache für relationale Datenbanken zur parametrisierten automatischen Erzeugung von Web-Eingabemasken',
#  'Konzeptionierung und Realisierung einer rückgekoppelten, lernenden Textsuchkomponente',
#  'Zusammenführung von theoretischen Informationsmodellen und realem Informationsworkflow und Berücksichtigung vorhandener unternehmerischer Sichten zur Einführung eines Dokumentenmanagementsystems',
#  'Optimierung und Weiterentwicklung des Referenz Clock Generators von GSM-Basisstationen',
#  'Projektierungstool für die Anzeigensteuerung der Fahrgastinformation',
#  'Realisierung eines Workflows für das Bewerbermanagement mit Internet-Technologie',
#  'Netz-Erneuerung für die BOSCH-Niederlassung Nürnberg',
#  'Dokumentenmanagementsystem für Präsentationen',
#  'Entwicklung einer Toolumgebung für eine Hochleistungsmotorsteuerung',
#  'Prozessorientiertes Qualitätsmanagement in einem mittelständischen Dienstleistungsunternehmen am Beispiel der DATA INPUT AG',
#  'eProcurement-Systeme für KMU-Einsatzszenarien, Technologien und Soft-warekomponenten',
#  'Reengineering of a legacy sales information system with respect to Customer Relationship Management (CRM) and the Internet, including an implementation of a certain component',
#  'Konzeption und Implementierung eines Web-Portals zur Darstellung aktueller Unternehmenskennzahlen und dessen Integration in die vorhandene Infrastruktur',
#  'OBIS - Observation and Information System auf Lotus-Notes-Basis',
#  'Konzeption einer User Interface Adaption für mobile Webgeräte',
#  'Entwurf und Implementierung eines ISDN-Stacks unter dem Echtzeitbetriebssystem EUROSplus',
#  'Konzeption und Design eines graphischen Entwicklungswerkzeugs für internetbasierte Informationssysteme',
#  'A generic, computer-based approach to the estimation of asset lifetimes',
#  'Ein Einblick in moderne Methoden des Requirements Engineering ',
#  'Leitlinien zur innerbetrieblichen Verrechnung der IT-Leistungen in einem Versicherungsunternehmen',
#  'Changes of business processes and public presentation within the influence of modern media',
#  'Konzeption und Implementierung eines Moduls zur flexiblen Anbindung von Speditionsunternehmen an Internet-Marktplätze.',
#  'Evaluierung der Entwicklungswerkzeuge DYMOLA und MODELICA durch beispielhafte Entwicklungen von mechatronischen Systemkomponenten',
#  'Werkzeugunterstützte Modellierung von Anlagen mit UML',
#  'Ein prototypischer Container für die CEA-Komponenten-Architektur',
#  'Design of a customising process and a meta-data model for a key figure-based information system, with focus on the configuration of a key figure model',
#  'Computergestützte Datenerhebung mit dem Internet; Entwicklung eines Front-End-Editors zum Erstellen von Online-Umfragen',
#  'Wiederverwendbare Analysemuster auf der Basis natürlich sprachlicher Anforderungen',
#  'Vergleichende Studie von Distance-Vector-Routing-Protokollen und Link-State-Routing-Protokollen',
#  'Konzept zur Implementierung einer Schnittstelle zwischen dem Planungstool "ProPlanner" und der Arbeitsplan-Datenbank in der  Prozessplanung der BMW Group.',
#  'Konzept zur Migration von Datenmodellen bei der Firma DATEV in UML-Klassendiagramme und seine Implementierung',
#  'Entwurf und Implementierung eines Systems zur Einschreibung zu den Fachwissenschaftlichen Wahlpflichtfächer am Fachbereich unter Benutzung des WWW.',
#  'Modellgestützte Analyse und Synthese von Gesichtsbildern',
#  'Extraktion navigationsrelevanter Daten aus vorverarbeiteten Stereobildern mit Hilfe eines simulierten neuronalen Netzes.',
#  'Entwurf und Implementierung eines standardisierten Hantierungs-werkzeugs für die Verwaltung von Sortierplänen im Bereich Distributionslogistik',
#  'Der Softwareauswahlprozess am Beispiel einer Internet-Suchmaschine mit Detailplanung der Softwareeinführung',
#  'Analyse und Neustrukturierung eines Firmen-LANs - Migration von Token Ring zu Switched-Ethernet und Erstellung eines VLAN-Konzepts mit Einbindung in ein Netzwerkmanagementsystem',
#  'Unsicherheit und Unschärfe bei Bewertung und Aggregation von Risiken  in einem Risikomanagementsystem. Simulationsrechnungen für ein Modell eines produzierenden Unternehmens.',
#  'Einführung eines webbasierten Qualitätsmanagementsystems bei  einem IT-Dienstleister',
#  'XML-Datenhaltungs- und Datenaustauschplattform für das Verlagswesen?',
#  'Application of a Web-Controlling Instrument in the Insurance  Industry for the Example of Quelle Versicherung',
#  'Räumlich verteilte und gleichzeitige Bewertung visualisierter  medizinischer Bilddaten. Analyse der Anforderungen, Entwurf und Implementierung eines Prototyps',
#  'Cobol & Objektorientierung - ein Vergleich zwischen objekt-orientierter und prozeduraler Implementierung ',
#  'Konzeption und Implementierung einer Architektur zur modularisierten  Daten aus einem OSGi-Server in einem Browser unter Verwendung von XML',
#  'Analyse der ISO 9000 ff-Abläufe bei der ISO Software Systeme GmbH und Entwurf einer Web-gestützten Anwendung zu deren Unterstützung',
#  'Der Modellbildungsprozess in der Wirtschaftsinformatik: Erkenntnis- theor. Reflexion des Spannungsfeldes zwischen Modell und Realität in ausgewählter Literatur unter besonderer Berücksichtigung des naiven Realismus (Arbeitstitel)',
#  'Konzeption und Aufbau eines Systems zur Qualitätssicherung in der Softwareentwicklung von Audio-Datenkompressionsverfahren',
#  'Konzeption eines pragmatischen Geschäftsprozessmodells für den technischen Vertrieb von IT-Sicherheitslösungen ',
#  'Bewertung, Vergleich und Erweiterung von UML-basierten Ansätzen zur objekt-orientierten Modellierung von Echtzeitsystemen.',
#  'Concept for an Automated Web-based Customer Relationship Management System for a Web-Design Company. ',
#  'Planung und Realisierung eines Internetportals für christl. Jugendarbeit',
#  'Analyse, Design und Implementierung eines Werkzeugs zur Modellierung und Erzeugung von Datenbanken unter Verwendung des Entity-Relationship-Modells',
#  'Design and Prototyping of a Secure Network File System under Linux on the Basis of Open SSH',
#  'Knowledge Management: Theorie, Werkzeuge und Ziele, sowie deren Anwendung für die Wissensbasis eines Software-Hauses',
#  'Konzeption und Implementation eines Simulationsmoduls für ein SA/RT-Case-Tool',
#  'Realisierungsplattformen für Webservices - Bewertung von Leistungs-umfang und Unterstützung relevanter Technologiestandards',
#  'Aufbau,Inbetriebnahme und Test eines netzwerkorientierten Intrusion Detection Systems',
#  'Analyse des bestehenden Reportings und Konzeption eines analytischen Informationssystems für das PC-Service-Management in einem EDV-Dienstleistungsunternehmen.',
#  'Entwurf und Entwicklung eines Prototyps für ein wissensbasiertes System zur Unterstützung der Konfiguration variantenreicher Büromöbeleinrichtungen',
#  'JPEG2000 - Einsatzmöglichkeiten im medizinischen Bereich',
#  'Erweiterung der Videocodierung H.263 zur segment- und modellbasierten Kompression bewegter Gesichtsbildfolgen',
#  'Erhöhung der Netzwerksicherheit durch den Einsatz von Intrusion Detection Systemen - eine Analyse hinsichtlich Effektivität und Wirtschaftlichkeit',
#  'Application Service Providing und daraus resultierende Anforderungen an Service Level Agreements sowie an Konzepte zur Datenhochverfügbarkeit',
#  'Realisierung einer Softwareplattform für kundenspezifische Prüfsysteme',
#  'Simulation und Entscheidungsfindung - Entwicklung eines Verkehrssimulationssystems mit Simplex III zur Ableitung von mikro- und makroskopischen Entscheidungen',
#  'Analogisches Denken als eine mögliche Erkenntnisstrategie zur Modellbildung in der Wirtschaftsinformatik',
#  'Testing and Software Rehability with a Special Regard to Component-Based Software',
#  'Analyse aktueller Wissensmanagement-Konzepte und Darstellung einer möglichen Umsetzung in der betrieblichen Praxis am Beispiel der Quelle Versicherungen',
#  'Grundlagen für ein Konzept zur Einführung von Wissensmanagement in einem Ingenieurbüro zur Verbesserung der Geschäftsprozesse',
#  'Enterprise JavaBeans Relationship Service',
#  'Knowledge Management',
#  'Planung und Programmierung einer hierarchischen Benutzerverwaltung auf Basis eines LDAP-Servers und Bereitsstellung geeigneter Systemschnittstellen',
#  'Konzeption und Implementierung eines Java-Programms zur Steuerung der Testumgebung für ein Raumsondenexperiment',
#  'Entwicklung eines Linux basierenden Firewall der mit beliebig vielen Partnern kommunizieren kann, welche dynamische IP Adressen verwenden. ',
#  'Implementierung eines OPC-Servers unter dem Echtzeitbetriebssystem EUROSplus auf DCOM-Basis',
#  'Fachkonzept für die Entwicklung des Programms Kraftfahrzeugsteuererklärung ',
#  'Ein EDV-gestütztes Modell zur Unterstützung von Computer Aided Facility Management-Software-Auswahlprozessen',
#  'Entwicklung und Pilotierung einer Application Service Providing-Dienstleistung auf Basis der Windows Terminal Server-Technologie bei der DATEV eG',
#  'Konzeption und Realisierung einer natürlichsprachlichen Benutzerschnittstelle für ein System zur Entdeckung von Wissen in Datenbanken',
#  'Entwicklung einer Empfängersteuerung für digitalen Lang-, Mittel-, Kurzwellenrundfunk',
#  'Theoretische Grundlagen und prototypische Implementierung eines anomaliebasierten NIDS',
#  'Automatisierung von Unit Tests in der objektorientierten Software-Entwicklung - Eine Fallstudie am Beispiel der Touristik-Software OCEAN -',
#  'Forward und Reverse Engineering für Automotive Software unter Verwendung der UML und Java',
#  'Analysis, Conception and Implementation of a project planning software based on the ERP-System NAVISION Attain',
#  'Erstellung eines Modells von standardisierten CRM-Prozessen in Anlehnung an den Business Development Process nach M. Gerber am Beispiel einer EDV-Firma',
#  'Concept of Project Management Software based on the analysis of a generalized Project Management Process.',
#  'Conception of a Business Process Modeling Tool with the Focus on Information Management Aspects',
#  'Konzeption und Entwicklung eines prototypischen Steuerungssystems für die Überwachung eines international verteilten Produktionssystems',
#  'Parallelisierte Lösung von partiellen Differentialgleichungen',
#  'Entwicklung einer datenbankbasierten Internet Applikation auf Basis des Oracle Internet-File-System unter Berücksichtigung der Regeln der Informationssicherheit. Analyse der Stärken und Schwachpunkte.',
#  'Entwicklung einer Schnittstelle zur Konfiguration eines Datenbanksystems auf Basis einer UML-Datenmodellbeschreibung',
#  'Geschäftsprozessoptimierung im Bereich der Rechnungsprüfung bei der Siemens AG ',
#  'Application Service Providing (ASP) aus Sicht der DATEV - Geschäftsmodellierung des Einführungsprozesses der Dienstleistung DATEVasp und Ermittlung dazugehörender Kennzahlen zur Messung der Kundenzufriedenheit',
#  'Extension of the Imaging & Visualization Toolkit (IVT) for a CT based Colon Polyp Detection Application ',
#  'Entwicklung einer Internetapplikation zur Reklamationsbearbeitung für den Einzelhandel unter Verwendung eines LAMP-Systems.(Linux-Apache-MySQL-PHP)',
#  'Anbindung von Kleinstandorten mit begrenzten Ressourcen an die homogene Windows 2000 PC-Infrastruktur des Siemens Konzerns',
#  'Visualisierung von Datenvolumen mit programmierbaren Shadern und Texturen auf PC Hardware',
#  'Design und Realisierung eines intelligenten Fachregals zur Unterstützung von Werkern in Montageprozessen',
#  'Control and Simulation of Mobile Phone Layer 1 without Layer 3 support',
#  'Konzeption und Implementierung eines Registrations-Robot für Internet-Domains',
#  'Automatisierte Zuordnung fachbezogener Bewerberprofile zu vorhandenen Stellenprofilen in einer Datenbank',
#  'Unterschiede und Gemeinsamkeiten von Wasserzeichenverfahren in verschiedenen Medien',
#  'Entwicklung und prototypische Implementierung der zentralen Software-Komponenten eines Akustikmoduls für die akustische und graphische Repräsentation von Signalen eines Körperschallüberwachungssystems.',
#  'Konzeption und prototypischer Entwurf einer Web-Applikation zur Produktaktualisierung bei mittelständischen Softwareunternehmen unter Verwendung von Java Servlet und JavaServer Pages Technologien',
#  'Konzeption einer integrierten Softwareunterstützung für das Projektmanagement in der Automobilentwicklung am Beispiel des SAP-R/3-Projektsystems',
#  'Entwicklung eines Reparatursystems zur automatischen Behebung von zentralen Fehlern eines Linuxsystems.',
#  'Untersuchung der Eignung von JAVA für den Einsatz in einem Bildverarbeitungs-System unter Embedded Linux',
#  'Verwendung von XML zur Unterstützung von sprachgesteuerten und sprachwiedergebenden Anwendungen für den Pocket PC',
#  'Design, Konzeption und Realisierung einer ergonomisch gestalteten WWW-Oberfläche am Beispiel eines Kartenreservierungssystems.',
#  'Konzepterstellung und Realisierung einer Einbindung von Linux für IBM Mainframe in den bestehenden Rechenzentrumsbetrieb',
#  'Bewertung und praktische Anwendung von Hard- und Softwarelösungen zum Betrieb hochverfügbarer Serversysteme unter Linux und Windows',
#  'Entwurf und Implementierung eines standortübergreifenden Kommunikationskonzeptes für den Konzerninternen Informationsaustausch',
#  'Evaluation der Sicherheitskriterien für sensible Firmendaten im Internet anhand des Internet-Portals www.logistik.top100.de und Umsetzung einer technischen Lösung zur Reduzierung dieser Gefahren.',
#  'Integration eines Bildschirm-Rekorders in eine medizinische Workstation und Bewertung des Ergebnisses anhand des Beispiels der virtuellen Kolonoskopie',
#  'Hochsprachen für die Programmierung moderner GPUs (Graphic Processing Units). Analyse ihrer Einsatzmöglichkeiten in der medizinischen Bildverarbeitung anhand beispielhafter Implementierungen ausgewählter Algorithmen.',
#  'Untersuchungen zur interaktiven Übertragung komprimierter Bilddaten mit JPEG2000 mittels CORBA',
#  'Implementierung eines Softwaremodells der Übertragungskette beim digitalen Kurzwellenrundfunk "DRM"',
#  'Konzeption einer Anwendung f.d.Ermittlung, zentr.Speicherung u.Veröffentlichung v.Ist-Ertrag-Daten netzgekopp.photovoltaischer (PV) Anl.m.anschl. prototypischer Gestaltung einer Internet-Benutzerschnittstelle f.d.Visualierung der PV-Anl. u. PV-Ist-Erträge',
#  'Technische Grundlagen für Performance- und Verfügbarkeitsmanagement in einer Application Service Providing-Realisieerung',
#  'Ein generisches Vorgehensmodell für die Spezifikation von Anforderungen an die Benutzerschnittstelle komplexer Systeme',
#  'Möglichkeiten der Ingegration der ERP-Systeme SAP R/3 und BaaN IV am Beispiel der Fusion zweier multinationaler mittelständischer Unternehmen.',
#  'Realisierung eines Web-Client für Siebel-CRM-Software auf Basis von Java-Technologien',
#  'Erstellung eines Verzeichnisdienstes auf LDAP-Basis für die Administration eines Linux-/Unix-Netzes',
#  'XML-unterstützte Generierung graphischer Dialogkomponente für Java Applikationen im Bereich Logistik/Lagerhaltung',
#  'Durchsatz- und Eignungsvergleich unter Embedded Linux von Sockets, ACE Framework und CORBA als Kommunikationsmechanismen zur Übertragung großer Datenmengen',
#  'Konzeption einer integrierten Softwarelösung für die Personalkostenplanung in SAP R/3 am Beispiel der Automobilindustrie',
#  'Mehrläufigkeit im praktischen Vergleich auf Basis der aktuellen Technologien von SUN und Microsoft.',
#  'Konzepte der Kommunikation und Verteilung',
#  'Konzepte der Kommunikation und Verteilung',
#  'Entwicklung von Internet- und Intranetanwendungen mit dynamischen Businessgrafiken und Tabellen - Untersuchung und Vergleich von PHP4, Javascript und HTML mit den neuen .NET-Programmiersprachen VB.NET und C#.NET anhand konkreter Anforderungen.',
#  'Untersuchungen zu Sicherheitskonzepten für die Kommunikation und Übertragung großer Datenmengen von embedded Multimedia Geräten.',
#  'Entwurf und Implementierung einer Systemarchitektur für XML-basiertes Publishing am Beispiel eines Data-Warehouse Systems.',
#  'Systemintegrierte Investitionsplanung in der Digitalen Fabrik mit SAP, Delmia und J2EE',
#  'Analyse von Verhaltensmustern sowie Entwicklung geeigneter Methoden zur Erkennung und Behandlung von Web-Spidern aus Sicht von Internet-Inhaltsanbietern.',
#  'Untersuchung des Bluetooth-Stack "BlueZ" der als Linux-Kernel-Modul realisiert ist und dessen Inbetriebnahme auf einer 80x86 Architektur. ',
#  'Anwendungsintegration bei Workflow-Management-Systemen',
#  'Data Mining und deutsche Verbalmorphologie',
#  'Data Mining und russische Verbalmorphologie',
#  'Der Markt des Spielwaren-Einzelhandels in Nürnberg ',
#  'Prototypische Realisierung eines ActiveX-Control zur Visualisierung eines vorgegebenen Volumenmodelles',
#  'Zertifizierung von OLE Compound-Dokumenten und PE-Files mittels digitaler Signaturen. ',
#  'Entwurf und Implementation einer IPsec-basierten Absicherung von offenen Netzwerken unter Linux.',
#  'M A S T E R A R B E I T :  Dynamische Speicherstruktur für geometrische 3-dimensionale Objekte und deren hierarchischer Organisation in einem Szenegraphen',
#  'Verwendung der 3D-Beschleunigungseinheit moderner Graphikkarten zur hardwarebeschleunigten Berechnung verschiedener Algorithmen in der Bildverarbeitung',
#  'Konzeption und Realisierung eines Software-Agenten zum Einholen von Angeboten im Internet mit Verwendung von Branchenwissen ',
#  'Multi-Volumen Rendering für medizinische Datensätze',
#  'Verteilte Anwendungen auf der Basis Mobiler Agenten',
#  'Konzeption und Realisierung eines Unterstützungssystems zum Management kundenspezifischer Konfigurationen von Anwendungssoftware für das Dokumentenmanagement',
#  'Entwurf und Implementierung eines abgesicherten zentralen Servers zur Anmeldung und Verwaltung globaler Sessions',
#  'Design eines Frameworks zur schnellen Entwicklung von Web-Anwendungen auf Basis des V-ger-Produktservers',
#  'Entwicklung eines internetbasierten, datenbankgestützten Business-to-Consumer Portals mittels Techniken der Java2 Enterprise Edition',
#  'Konformitätsprüfung von Structured Reports nach dem DICOM-Standard',
#  'Bestimmung von wesentlichen Systemqualitätsparametern mit statistischen Analysen auls Patientenbilddaten von Magnetresonanzanlagen',
#  'Vergleich der Umsetzung Aspekt-orientierten Programmierens in verschiedenen Frameworks',
#  'Objektpersistenz unter Java - Eine Gegenüberstellung aktueller Verfahren am Beispiel des Datenmodells einer Content-Management-Webapplikation',
#  'Konzeption und Implementierung eines Rahmenprogramms zur Demonstration von Softcomputingverfahren mit Beispielimplementierungen',
#  'Erarbeitung von Richtlinien und Entwicklung eines grundlegenden Frameworks zur komponentenbasierten Softwareentwicklung unter .NET',
#  'Untersuchungen und Vergleich verschiedener Echtzeit-Betriebssystem-Implementierungen für den Einsatz im Highspeed-Mulitmedia-Bereich',
#  'Implementation and Evaluation of Pentium 4 - Optimizations in the Audio Codec mp3PRO.',
#  'Konzeption und Realisierung einer Lösung zur zuverlässigen Erkennung von Spam-Mails im Emailsystem einer Versicherungsgruppe.',
#  'Annuitätentilgung von Darlehen und Renten mit numerischer Berechnung des effektiven Zinssatzes',
#  'Konzeption und Realisierung einer Operation- and Maintance-Anwendung zur Visualisierung und Überwachung von Testsystemen der Sigos SITE-Plattform',
#  'A Pragmatic Approach to Automation of Office Process and Workflows',
#  'Erstellung einer T9-Worterkennungs-Software für Windows PCs',
#  'Enterprise Application Integration mit J2EE und der Java Connector Architecture - Das eFactory Beispiel Delmia PPR-Hub',
#  'Konzeption und Implementierung eines XML-basierten Schnittstelle zur Nutzung von Internet-Diensten in einem Workflow-Management-System',
#  'Konzeption und prototypische Realisierung eines Frameworks zur Unterstützung der Erzeugung, Installation und Verwaltung von kundenspezifischen Softwarekomponenten ',
#  'Evaluierung der Spezifikation der Business Process Execution Language for Web Services und prototypische Integration in ein Informationsmanagementsystem',
#  'Konzept und Implementierung einer Testautomatisierung über die graphische Oberfläche von Qt-basierenden Applikationen.',
#  'Entwicklung einer selbst konfigurierbaren Web Applikation für Klein- und Mittelbetriebe zur Erstellung von Dealer-Locator-Solutions',
#  'Konzeption, Machbarkeitsstudie und prototypische Umsetzung eines webbasierten Mitarbeiterprotals zur Personaleinsatzplanung und Zeitwirtschaft',
#  'Algorithmen zur Segmentierung der CT-Volumen-Daten von Körpern technischer Werkstoffe aus mehreren Materialien',
#  'Entwicklung eines webgestützten Systems zur Evaluation von Lehrveranstaltungen',
#  'Ein objektorientierter Ansatz für die Einbindung von Grafiken in Produktdokumentation am Beispiel von Logikdiagrammen',
#  'Der sichere PC-Herausforderungen, Chancen und Risiken der Trusted Computing-Initiativen auf den internen PC-Einsatz der DATEV eG',
#  'Entwurf eines Konzepts zur nutzerfreundlichen Verschlüsselung von ISDN-Telefonie',
#  'Bewertung und Vergleich alternativer Authentifizierungsmethoden im Bereich der PC-Zugangskontrolle',
#  'Eignung internetbasierender Single-Sign-On-Verfahren für die Automatisierungstechnik',
# ...
#  'Konzeption der Zusammenführung von Applikationen zu Unternehmensstrukturen auf Basis von .NET',
#  'Analyse zur Bestimmung geeigneter Untersuchungspartner für die atemkorrelierte Mehrschicht-Spiral-CT',
#  'Entwurf und Entwicklung eines Simulators für das Kommunikationsverhalten von Steuergeräten in Bussystemen ',
#  'Analyse der SAP ERP Best Practice Geschäftsprozesse für die Geschäftsprozessharmonisierung im Controlling bei der Geschäftseinheit PTD der Siemens AG',
#  'Design und Realisierung eines regelbasierten Systems zu Fakturierung projekt- und kundenbezogener Kosten',
#  'Ontologiebasierte Verwaltung von Informationsstrukturen - Erstellung, Integration und Pflege am Beispiel Microsoft SharePoint',
#  'Erstellung eines Konzepts zum Offshare-Outtasking des Applications Monitoring der Schaeffler KG',
#  'Chargenverfolgung mit SAP bei einem weltweit agierenden Automobilzulieferer: Schwachstellenanalyse und Verbesserung von Logistikkprozessen',
#  'Online Assessment System für E-Commerce Portale',
#  'Entwicklung eines Erkennungsalgorithmus für DDoS-Angriffe von Botnetzen zur Integration in das Internet-Analyse-System am Beispiel des Storm-Worm',
#  'Integration eines ICA-Clients der Firma Citrix sowie Analyse, Evaluierung und Performancevergleich mit weiteren Remote-Protokollen auf Basis der ARM-Plattform',
#  'Grafisch-und Skript-gesteuerte Prozessdaten-Simulation und -Auswertung zwecks Verifikation einer programmierbaren Ablaufsteuerung und der dazugehörigen Steuerungsprogramme',
#  'Der Betrieb mobiler Geräte in einem selbstkonfigurirenden IPV6-Netzwerk',
#  'Untersuchung aktueller Software-Ergonomie-Studien und Erstellung eines Leitfadens zur Entwicklung von zielgruppenorientierter, ergonomischer Webanwendungen',
#  'Systemplattform für Condition-based Monitoring bei Produktionsmaschinen',
#  'RFID in mobile environments as a component of Supply Chain Management',
#  'Representation and usage of qualitative similarity in semantic search',
#  'Generische Widgeterstellung zum Einbinden in verschiedene Benutzer-erweiterbare Internetplattform',
#  'Konzeption und prototypische Implementierung eines workflow-basierten Personalvermittlungsprozesses für Microsoft Office Sharepoint Server und Microsoft Dynamics CRM',
#  'Information Retrieval mehrdimensionaler Retrievalobjekte unter Nutzung flexibel integrierbarer Ähnlichkeitsmaße',
#  'Analyse und Optimierung der Verteilung von Komponenten in PC basierten Stationsleitsystemen',
#  'Entwicklung eines Replay-Mechanismus für eine Rule-Engine unterstützt durch ein Online-Monitoring-System',
#  'Konzeption und Realisierung eines betriebswirtschaftlichen Analysesystems auf der Basis von Microsoft Dynamics AX unter Verwendung des Microsoft SQL-Servers sowie des Cubeware Importers',
#  'Evaluierung des End-to-End Management und entsprechender Tools bei Siemens Medical Solutions',
#  'Approximative Lösung des TSP-Problems durch einen erweiterten Partikel-Schwarm Algorithmus (PSO) in Matlab und Vergleich mit einer heuristischen Verarbeitungsweise',
#  'Formulierung, Analyse und Überprüfung neuer Software - Zuverlässigkeitsmodelle',
#  'Analyse moderner Virtualisierungstechniken und ihr Einsatz in der Medizin',
#  'Semantic Correctness of Compiler Optimizations',
#  'Entwicklung eines Konzepts zum Einsatz von Supplier Management im Bereich Outsourcing von Servicedienstleistungen und Anwendung anhand des Einführungsprozesses von DATEVasp compact',
#  'Werkzeugunterstützte Optimierung der Übersetzung im Aktualisierungsprozess mehrsprachiger Anwendungen',
#  'Evaluierung der Integrationsmöglichkeiten des neuen elektronischen Handels- und Unternehmensregisters (EHUG) im Geschäftsfeld der DATEV Wissensvermittlung',
#  'Konzeption und Realisierung eines Eingabeassistenten für Fehler- und Änderungsmeldungen im Konstruktionsprozess',
#  'Aufbau eines PLM-Schowrooms mit Hilfe von UGS Teamcenter zur Darstellung der Optimierungspotentiale durch Produktlebenszyklusmanagement (PLM)',
#  'Einführung in Navision - Entwurf eines geführten Praktikums',
#  'Evaluierung bei der Atos Origin unterstützten Enterprise Content Management-System anhand einer Nutzweranalyse, die auf Basis von spezifischen aus Prozessen resultierenden Kundenanforderungen erstellt sind.',
#  'Verfahren zur GPS gestützten Visualisierung von Testfahrten in geographischen Karten im Rahmen der Entwicklung von Mobiltelefonplattformen',
#  'Untersuchung der Oberflächenschicht der DATEV-Steuerprogramme für die Migration in eine serviceorientierte Architektur',
#  'Visual development of access control policies',
#  'Vergleich und Analyse der Einsatzmöglichkeiten von Webservices und Message Queues anhand eines Kurzmitteilungsdienstes einer Webanwendung der Immowelt AG',
#  'Konzeption und exemplarische Implementierung eines Generators für Softwaremodule aufbauend auf einem Framework zur Zählerkonfiguration',
#  'Implementierung eines modellbasierten 3D-Gesichts-Trackers',
#  'Funktionale Modellierung einer automatisierungstechnischen Anlage mit der Microsoft Visual Programming Language VPL',
#  'Softwaremanagement of a Linux-based computer as a distribution-independent Service',
#  'Datenbankbasierte Anwendung von Regeln auf einem Data Mining Prozess am Beispiel von natürlich sprachlichen Verbalmorphologien',
#  'Ermittlung einer kostengünstigen Lösung im Bereich Raumautomation unter Verwendung von Siemens EIB/KNX Geräten',
#  'Intranet-Tool zur Sortierung von Detektormodulen eines Computertomographen',
#  'Webbasierte Lernanwendung mit Stifteingabe und Hot-Potatoes als Lernmaterialquelle',
#  'Computerunterstütztes Lernen',
#  'Entwurf und Implementierung eines Programms zur Steuerung eines Geräts für Tastenbestätigungstests',
#  'Virtualization in Wireless Networks',
#  'Interaktive Bildfilterung entlang der Herzphase zur kardialen Computertomographie',
#  'Analyse, Bewertung und prototypische Umsetzung der Nutzung von TPM (Trusted Platform Modelle) für Kommunikations- und Sicherheitsszenarien in Steuerkanzleien ',
#  'Business Intelligence und seine Beziehungen zu Data Warehouse, Data Mining und OLAP ',
#  'Untersuchung des "Software & Systems Process Engineering Metamodel" auf Praxistauglichkeit anhand der Modellierung eines existierenden Engineering-Prozesses  ',
#  'Entwicklung einer browserbasierten eLearning-Software mit Perl',
#  'Dynamische Anpassung der Kodierparameter für die IP-basierte Audioübertragung',
#  'Optimierung der Integration von Verpackungsmaschinen in Verpackungslinien - Demonstration an einem Demo Modell',
#  'Entwicklung eines Konzepts zur Implementierung einer "On-Screen-Tastatur" in Panels und PC basierenden Systemen',
#  'Konzeptionierung und Implementierung eines kollaborativen Systems auf Tablet-PC Basis  ',
#  'Creation of a mobile phone application for secure voice transmission and reception',
#  'Klassifikation von Dateisystemen auf Basis von Ontologien mit Hilfe von Lernalgorithmen',
#  'Konzeption und prototypische Implementierung der Visualisierung von Kennzahlen im "DATEV Arbeitsplatz"',
#  'Konzeption und prototypische Implementierung eines Management-Cockbits für das Kennzahlen-Monitoring in einer Steuerkanzlei',
#  'IEEE 802.1X - Port-Based Network Access Control in der Schaeffler Gruppe',
#  'Der Prozessnavigator als Entscheidungshilfe im Entwicklungsprozess - Einsatzanalyse in industrieller Umgebung und prototypische Umsetzung eines Teilprozesses mit Evaluierung',
#  'Entwicklung und Implementierung eines industriellen Lasersteuersystems, auf Basis einer echtzeitfähigen Schnittstellenkarte',
#  'Konzeption und Entwicklung einer datenbankgestützten Internetplattform für modulbasierte Standard- und Spezialanwendungen',
#  'Evaluierung von SAP NetWeaver Master Data Management am Beispiel einer rollenbasierten Berechtigungsverwaltung',
#  'Konzeption einer PLM-Architektur für einen Siemens Geschäftszweig mit Fokus auf dem Produktdatenmanagement',
#  'Entwicklung von Verfahren für mobile, Roboter gestützte Röntgencomputertomographen',
#  'Automatisches Erstellen von XSLT Skripts für die XHTML Generierung',
#  'Extraction and Understanding of Domain Specific Geographical Information in Unstructered Text',
#  'Vergleich dreier Entwicklungsumgebungen für die Realisierung von Rich-Clients: Eclipse, NetBeans und .NET',
#  'Virtuelle Geldbörse für Schulen auf Smartcard-Basis',
#  'Standardisierung der Prozesse für internationale Rollouts von zentralen Client-Server Applikationen am Beispiel SAP-PLM',
#  'Visualization of differences between EMF models',
#  'Analyse und Entwicklung eines Unified Remote Service Graphical User Interface zur Steigerung der Bedienbarkeit und der Kundenzufriedenheit innerhalb des Siemens Remote Service ',
#  'Funktionales Programmieren in C#',
#  'Integration von Geschäftsdaten aus Dynamics NAV in den SharePoint-Server',
#  'KPI System for Performance Optimization in Different Airport Baggage Handling Systems',
#  'Reintegration der Dateien in einem Offline-Dateisystem unter Linux mit grafischer Benutzerführung',
#  'Konzeption und Implementierung eines Integrationsszenarios für den Datenaustausch von SAP- mit Non-SAP-Systemen unter Verwendung des Microsoft BizTalk Servers in der Siemens AG',
#  'Systemdiagnose in verteilten MES-Systemlandschaften am Beispiel SIMATIC IT',
#  'Entwurf und Implementierung eines MVC-basierten objektorientierten Frameworks mit PHP5',
#  'Elektronische Produktanlage - Bestandsaufnahme von Datenflüssen im PBS-Markt aus Sicht eines mittelständischen Produktionsunternehmen',
#  'Konzeption und Realisierung einer ontologiebasierten Kompetenzverwaltung für die Fakultät Informatik',
#  'Sicherer Datenverkehr zwischen Steuergeräten auf Basis der Automotive Open System Architecture (AUTOSAR)',
#  'Konzeptionierung einer Ressourcenplattform bei der evosoft GmbH',
#  'Optimierung des räumlichen Inferenzverfahrens MAP3 und Realisierung als Location Middleware',
#  'Konzeptstudie zur Kernelsoftware für SIMATIC-Steuerungen auf Multicore-Prozessoren',
#  'Effiziente Implementierung einer feingranularen Zugriffskontrollsprache',
#  'Boutiquenkette SOHO: Mode-Marketing in Russland',
#  'Modellierung von Dienstleistungsketten bezüglich Planung und Verfolgbarkeit',
#  'Integration einer Hardwareabstraktionsschicht (Fosstrak) in eine existierende RFID-Middleware (SMMART)',
#  'Entwurf und Implementierung eines Benutzerverwaltungs-, Bewertungs- und Belohnungssystes zur Unterstützung des computergestützten Lernens',
#  'Data Mining im Einzelhandel- Warenkorbanalyse',
#  'Potentials of temporal blocking for stencil-based computations on multi-care Systems',
#  'Konzeptionierung einer Wissensdatenbank zur Speicherung, Analyse und Visualisierung von strategischen Informationen im  medizinischen Umfeld - Anforderungen aus der Sicht der Informationstechnologie',
#  'Integration einer 3D-Ansicht in das Oberleitungsprojektierungsprogramm "Sicat Master" mit Hilfe von DirectX 9.0 und C++',
#  'Entwicklung eines Frameworkprototypen auf .NET Basis für die Systemautomatisierung',
#  'Analyse von mit Geo-Tags versehenen Bilddateien und deren geographische Clusterung',
#  'Konzeption und Entwicklung eines regelbasierten Systems zur assistentengestützten Zielgruppenselektion für eine vertriebliche CRM-Komponente',
#  'Limitierung con Risikokennzahlen: Konzeption und prototypische Realisierung im SAP Bank Analyzer',
#  'Konzeption und Realisierung eines Geospatial-Add-Ons für SQL',
#  'Analyse und Konzeption einer datenbankgestützten Webanwendung zur Effizienzsteigerung des Project Reportings ',
#  'Effektives computergestütztes Lernen mit handschriftlichen Eingaben',
#  'Speicherzugriffs-Lokalität in paralellen Programmen mittels Speicher-Temperaturen',
#  'Applikation zur Berechnung von digitalen Filter',
#  'A feaseability study to integrate a virtual machine on an Infineaon Hardware/Software platform and if feasible an implementation of a "virtual core" bundled with an application to proof the concept ',
#  'Ablösung des SAP-Formularwesens durch ein kompatibles Output-Management-System für den Pilotstandort Weissenburg der LEONI AG  ',
#  'Die Microsoft Windows Workflow Foundation als Basis der IQ-optimize Workflow Eninge - Konzeptionierung und prototypische Implementierung ',
#  'Abstraktion des Datenbankzugriffes und der Datenschicht einer bestehenden PHP-Applikation',
#  'Medienorientierte Benutzeroberfläche zur Literatursuche',
#  'Analyse und Konzeption der statistischen Daten des Internetportals Immowelt.de und deren Übertragung in der Immowelt Maklersoftware',
#  'Evaluierung von Einsatzbereichen des Monitoring-Systems Nagios im Unternehmen',
#  'Portierung einer Prozessbeschreibung komplexer IT-Services unter der Berücksichtigung von wechselnden normativen Anforderungen lorarbeit: ',
#  'Optimierung eines  modellbasierten 3D-Gesichts-Trackers',
#  'Automatisiertes Setzen von Referenzpunkten im Gesicht zur Verbesserung von statistischen Modellen',
#  'Desktop-Virtualisierung in der DATEV eG - Untersuchung der Einsatzfähigkeit von Parallels Virtuozzo Containers für den internen Einsatz',
#  'Konzeption und Prototyp eines Frameworks zum Erstellen von grafischen Dialoganwendungen für mobile Datenfunkterminals',
#  'Entwicklung eines analytischen Verfahrens zur Positionierung von Prozesslogik in dynamischen, verteilten, hierarchischen IT-Netzen ',
#  'Komponenten und Konzepte moderner Verkaufplattformen im Internet und ihre marktpsychologischen Wirkungen',
#  'Entwicklung eines Leitfadens zur effizienten Prozessanalyse und -modellierung für die Einführung der elektronischen Vorgangsbearbeitung bei der Stadt Nürnberg ',
#  'Prototyp eines AUTOSAR-RTE-Dispatchers für Mehrkernsysteme',
#  'Portierung und Vergleich der Linux-Echtzeiterweiterungen Preempt-RT und Xenomai auf Basis einer ARM926-Plattform',
#  'Aufbau eines skalierbaren und hochverfügbaren Content Delivery Network',
#  'Spezifikation einer formalen Sprache zur benutzerfreundlichen Verifikation von FinTs Online Banking Transaktionen',
#  'Verteilung automatisierter und manueller Benachrichtigungen über verschiedenste Nachrichtenkanäle mit einer vom Anwender konfigurierbaren Logik',
#  'Prozess zur Spezifikation von Zugriffskontrollen in Webanwendungen am Beispiel des Softwareentwicklungsprozesses der Firma e:c:logic ',
#  'Instrumentierung und Management einer verteilten Web-Applikation',
#  'Konzeption und prototypische Umsetzung der Integration von OMNITRACKER mit Windows SharePoint Services und Microsoft Office SharePoint Server 2007',
#  'Entwurf und Implementierung einer realistischen Kreuzungsansicht für ein Navigationssystem basierend auf realen Straßengeometrien',
#  'Analyse, Entwurf und Implementierungvon Verfahren zur Koexistenz paralleler Netze basierend auf der existierenden proprietären Medienzugriffsschicht eines Multi-Hop Sensornetzes',
#  'Konzeption einer EDD-Testsuite für Oberflächen- und Grafikelemente',
#  'Wertorientierte Kundensegmentierung für eine differenzierte Kundenbearbeitung beim IT-Dienstleister PENTASYS AG',
#  'Generische SSL-Hardwarebeschleunigung mit Accelerator Cards unter Linux',
#  'System z Millicode Debugger - Entwicklung eines System z Millcode Debugger Plugins für Eclipse basierend auf einer Anbindung an den existierenden Millicode Emulator',
#  'Software zur Analyse der Schedulability in einem AUTOSAR basierten System',
#  'Analytische Steady-State Auswertung von Deterministisch-Stochastischen Petrinetze (DSPNs)',
#  'Konzeption und Implementierung einer PowerPC-Peripherie-Komponente in VHDL sowie zugehöriger Linux-Treiber-Software zum Tunneln einer Netzwerkverbindung über Xilinx RocketIO. ',
#  'Möglichkeiten der Mehrfingerbedienung bei der Dateiverwaltung',
#  'Konzeptueller Aufbau einer Adressclusterung und Anwendung verschiedener Clusterungsmethoden',
#  'Evaluierung und prototypische Realisierung einer Social CRM und Community Software Plattform auf Basis serviceorientierter Standardsoftware von Oracle',
#  'Konzeption und Implementierung eines IT-Systems zur Verwaltung und Bewertung von Kaizen-Maßnahmen bei der Schaeffler Gruppe',
#  'Harmonizing and Optimizing Apparel and Footwear Sales Processes for Sporting Goods Industry',
#  ...]

# %%
def preprocess(data):
    """Preprocesses and tokenizes the given theses titles for further use."""
    ### YOUR CODE HERE
    titles=[]
    for title in data:
        # Remove special characters and digits
        #title = re.sub(r'[^a-zA-Z\s]', '', title)
        # Convert to lowercase
        title = title.lower()
        
        tokens = nltk.word_tokenize(title)
    # Add start and end tokens
        tokens = ["<s>"] + tokens + ["</s>"]
    # Tokenize the text
        titles.append(tokens)
    
    return titles
    
    ### END YOUR CODE

# %%
theses_data = preprocess(load_theses_titles("./data/theses.tsv"))

# %% [markdown]
# ### Train N-gram Models
#
# 2.1 Train n-gram models with n = [1, ..., 5]. What about \<s> and \</s>?

# %%
import random
def build_n_gram_models(n, data):
    """
    To predict the first few words of the Tweet, we need the smaller n-grams as
    well. This method does calculate all n-grams up to the given n.
    """
    ### YOUR CODE HERE
    
    n_gram_models = {}

    for i in range(1, n+1):
        n_gram_model = {}
        for tweet in data:
            for j in range(len(tweet)-i):
                n_gram = tuple(tweet[j:j+i])
                if n_gram not in n_gram_model:
                    n_gram_model[n_gram] = []
                n_gram_model[n_gram].append(tweet[j+i])

        # Store the model
        n_gram_models[i] = n_gram_model
    return n_gram_models

    ### END YOUR CODE

# %%
n_gram_models = build_n_gram_models(5, theses_data)

# %% [markdown]
# ### Generate the Titles
#
# 3.1 Write a generator that provides thesis titles of desired length. Please do not use the available `lm.generate` method but write your own.
#
# 3.2 How can you incorporate seed words?
#
# 3.3 How do you handle </s> tokens (w.r.t. the desired length?)
#
# 3.4 If you didn't just copy what nltk's lm.generate does: compare the outputs.

# %%
# Notice: If you fix the seed in numpy.random.choice, you get reproducible results.
def get_suggestion(prev, n_gram_model):
    """
    Gets the next random word for the given n_grams.
    The size of the previous tokens must be exactly one less than the n-value
    of the n-gram, or it will not be able to make a prediction.
    """
    ### YOUR CODE HERE
    
    # Check if the previous tokens are in the n-gram model
    if tuple(prev) in n_gram_model:
        # Get the next word
        next_words = n_gram_model[tuple(prev)]
        # Choose a random word from the list
        return next_words[0]  # Replace with random choice if needed
    else:
        return None  # No suggestion available for the given previous tokens

    ### END YOUR CODE


def generate(n, n_gram_models, seed, title_length):
    """Generates a random tweet using the given data set."""
    model = n_gram_models[n]
    title= [seed]
    while True:
        prev = title[-(n-1):]
        if len(prev) < n:
            next_word = get_suggestion(prev, n_gram_models[len(prev)])
        else:
            next_word = get_suggestion(prev, model)
        if next_word is None or next_word == "</s>" or len(title) >= title_length:
            break
        title.append(next_word)
    return " ".join(title)

# %%
title_length = 20
seed_word =  "entwicklung"
thesis_title = generate(4, n_gram_models, seed_word, title_length)
print(thesis_title)

seed_word =  "saas"
thesis_title = generate(5, n_gram_models, seed_word, title_length)
print(thesis_title)
# Out:
# entwicklung eines plattformunabhängigen 3964r-treibers für windows-nt
# saas im kontext der anforderungen an ein erp-system
